# %% [markdown]
# # Clean the tennis data from the first site!

# %% [markdown]
# I am going to have a little play
#
# 1) Download a tennis results csv from the web
# 2) Play with the data
# 3) See if there are any nailed on conclusions or suggested patterns

# %%
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Set the current directory

cd C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\
# Out:
#   File "<ipython-input-8-4003628ff064>", line 3
#     cd C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\
#        ^
# SyntaxError: invalid syntax

# %%
# Find the data!

ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8636c5a6a93c> in <module>()
#       1 # Find the data!
#       2
# ----> 3 ls
#
# NameError: name 'ls' is not defined

# %%
# Import all of the excel sheets from [http://www.tennis-data.co.uk/] 

# Note the change in file format...?

Y2000_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2000.xls")
Y2001_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2001.xls")
Y2002_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2002.xls")
Y2003_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2003.xls")
Y2004_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2004.xls")
Y2005_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2005.xls")
Y2006_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2006.xls")
Y2007_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2007.xls")
Y2008_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2008.xls")
Y2009_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2009.xls")
Y2010_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2010.xls",
                          sheetname='2010')
Y2011_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2011.xls",
                          sheetname='2011')
Y2012_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2012.xls",
                          sheetname='2012')
Y2013_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2013.xlsx")
Y2014_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2014.xlsx")
Y2015_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2015.xlsx")
Y2016_data = pd.read_excel("C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\2016.xlsx")

# %%
# Check the column names are the same for 2000, 2012 and 2016

#list(Y2000_data)

#list(Y2012_data)

#list(Y2016_data)

# %% [markdown]
# ### Solution was to set the corect sheet of the file to read for years 2010,11 & 12.

# %%
# I have (hopefully!) stacked all the sheets on top of one another.

# Not sure what has happened where new variables are introduced on a year by year basis...?

df_to_concat = [Y2000_data,
               Y2001_data,
               Y2002_data,
               Y2003_data,
               Y2004_data,
               Y2005_data,
               Y2006_data,
               Y2007_data,
               Y2008_data,
               Y2009_data,
               Y2010_data,
               Y2011_data,
               Y2012_data,
               Y2013_data,
               Y2014_data,
               Y2015_data,
               Y2016_data,]

data2000_to_2016 = pd.concat(df_to_concat)
data2000_to_2016[:3]
# Out:
#    ATP  AvgL  AvgW  B&WL  B&WW  B365L  B365W  Best of  CBL  CBW  ...   UBW  \
# 0    1   NaN   NaN   NaN   NaN    NaN    NaN        3  NaN  NaN  ...   NaN
# 1    1   NaN   NaN   NaN   NaN    NaN    NaN        3  NaN  NaN  ...   NaN
# 2    1   NaN   NaN   NaN   NaN    NaN    NaN        3  NaN  NaN  ...   NaN
#
#     W1 W2   W3  W4  W5  WPts  WRank      Winner  Wsets
# 0  6.0  6  NaN NaN NaN   NaN     63  Dosedel S.    2.0
# 1  6.0  6  NaN NaN NaN   NaN      5  Enqvist T.    2.0
# 2  6.0  7    6 NaN NaN   NaN     40   Escude N.    2.0
#
# [3 rows x 54 columns]

# %%
data2000_to_2016[:2].T
# Out:
#                                              0  \
# ATP                                          1
# AvgL                                       NaN
# AvgW                                       NaN
# B&WL                                       NaN
# B&WW                                       NaN
# B365L                                      NaN
# B365W                                      NaN
# Best of                                      3
# CBL                                        NaN
# CBW                                        NaN
# Comment                              Completed
# Court                                  Outdoor
# Date                       2000-01-03 00:00:00
# EXL                                        NaN
# EXW                                        NaN
# GBL                                        NaN
# GBW                                        NaN
# IWL                                        NaN
# IWW                                        NaN
# ...

# %%
# I have exported this to the path:
# C:\\Users\\timothy\\Documents\\notebooks\\tennisBetting\\tennis_data_first_site\\combined_years_00_to16.csv


data2000_to_2016.to_csv('combined_years_00_to16.csv')

# %%
subset = cincinnati_df[['Winner','WRank', 'Loser', 'LRank']]
subset[:3]

#groupby Round
# Out:
#      Winner  WRank       Loser  LRank
# 0  Arazi H.     30    Coria G.     28
# 1  Blake J.    120  Boutter J.     57
# 2  Canas G.     33    Safin M.      3

# %%
rankng_difference_S = pd.Series(cincinnati_df['LRank'] - cincinnati_df['WRank'])
rankng_difference_S.mean()
# Out:
# 16.920634920634921

# %%
cincinnati_df['Round'].unique()
# Out:
# array(['1st Round', '2nd Round', '3rd Round', 'Quarterfinals',
#        'Semifinals', 'The Final'], dtype=object)

# %%
subset_group = cincinnati_df.groupby(['Round'])
subset_group.describe()
# Out:
#                      ATP  Best of        CBL        CBW        GBL        GBW  \
# Round
# 1st Round     count   32       32  28.000000  28.000000  28.000000  28.000000
#               mean    49        3   2.393214   1.795357   2.318929   1.709643
#               std      0        0   0.781381   0.843039   0.751440   0.683778
#               min     49        3   1.100000   1.180000   1.100000   1.150000
#               25%     49        3   1.850000   1.330000   1.800000   1.300000
#               50%     49        3   2.350000   1.525000   2.175000   1.550000
#               75%     49        3   3.000000   1.850000   2.825000   1.800000
#               max     49        3   4.250000   5.500000   4.100000   4.600000
# 2nd Round     count   16       16  16.000000  16.000000  16.000000  16.000000
#               mean    49        3   2.122500   2.045000   2.078125   2.035000
#               std      0        0   0.761030   0.819252   0.754941   0.920130
# ...
