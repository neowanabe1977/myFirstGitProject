# %%
import requests
import pandas as pd
import json

# %%
# ?requests

# %%
r = requests.get('https://data.gov.uk/api/3/action/package_show?id=manholes-in-devon')
r.content
# Out:
# b'{\n    "help": "http://data.gov.uk/api/3/action/help_show?name=package_show",\n    "success": true,\n    "result": {\n        "license_title": "UK Open Government Licence (OGL)",\n        "maintainer": null,\n        "groups": [],\n        "temporal_coverage-from": "",\n        "relationships_as_object": [],\n        "unpublished": "false",\n        "private": false,\n        "maintainer_email": null,\n        "num_tags": 0,\n        "foi-email": "",\n        "id": "91b3cd96-3ac1-4ad8-95df-25f06410fbec",\n        "metadata_created": "2015-07-14T14:34:09.121998",\n        "metadata_modified": "2015-07-14T14:34:09.141509",\n        "author": null,\n        "author_email": null,\n        "state": "active",\n        "version": null,\n        "archiver": {\n            "status": "Archived successfully",\n            "is_broken": false,\n            "reason": "",\n            "status_id": 0\n        },\n        "core-dataset": "false",\n        "temporal_coverage-to": "",\n        "licen
# ...

# %%
r = requests.get('https://data.gov.uk/dataset/manholes-in-devon')
r.json()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c01b48c1d332> in <module>()
#       1 r = requests.get('https://data.gov.uk/dataset/manholes-in-devon')
# ----> 2 r.json()
#
# /usr/local/lib/python3.4/dist-packages/requests/models.py in json(self, **kwargs)
#     803                     # used.
#     804                     pass
# --> 805         return complexjson.loads(self.text, **kwargs)
#     806
#     807     @property
#
# /usr/lib/python3.4/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     316             parse_int is None and parse_float is None and
#     317             parse_constant is None and object_pairs_hook is None and not kw):
# --> 318         return _default_decoder.decode(s)
#     319     if cls is None:
#     320         cls = JSONDecoder
#
# ...

# %%
# !usb-devices

# %%
# !apropos cd
# Out:
# apt-cdrom (8)        - APT CD-ROM management utility
# BN_gcd (3ssl)        - arithmetic operations on BIGNUMs
# cd-create-profile (1) - Color Manager Profile Creation Tool
# cd-fix-profile (1)   - Color Manager Testing Tool
# ecdsa (3ssl)         - Elliptic Curve Digital Signature Algorithm
# netcdf (3)           - Unidata's Network Common Data Form (netCDF) library in...
# netcdf_f90 (3f90)    - Unidata Network Common Data Form (netCDF) library, ver...
# netcdf_f77 (3)       - Unidata's Network Common Data Form (netCDF) library in...
# rpcdebug (8)         - set and clear NFS and RPC kernel debug flags
# rsyncd.conf (5)      - configuration file for rsync in daemon mode
# sbigtopgm (1)        - convert an SBIG CCDOPS file into a portable graymap
# tcdrain (3)          - get and set terminal attributes, line control, get and...
# XkbAllocDeviceInfo (3) - Obtain an XkbDeviceInfoRec structure
# XkbAllocDeviceLedInfo (3) - Obtain an XkbDeviceLedInfoRec structure
# ...
